# %%
from langchain_core.messages import AIMessage

ai_message = AIMessage(content="Message from AI")
ai_message.text
# Out:
# 'Message from AI'

# %%
from langchain_core.messages import HumanMessage

human_message = HumanMessage(content="Message from Human")
human_message.text
# Out:
# 'Message from Human'

# %%
history = [ai_message, human_message]
for m in history:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Message from AI
# ================================ Human Message =================================
#
# Message from Human

# %%
history + [AIMessage(content="Another message from AI")]
# Out:
# [AIMessage(content='Message from AI', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Message from Human', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Another message from AI', additional_kwargs={}, response_metadata={})]
