# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("claude-sonnet-4-20250514", temperature=0)
response = llm.invoke("Hello, I'm Fredy my number is 502 43434343")
response.text
# Out:
# "Hello Fredy! Nice to meet you. I should let you know that I can't actually call or text phone numbers, so I won't be able to use that number to contact you. \n\nIs there something I can help you with today through our conversation here? I'm happy to assist with questions, provide information, or just chat!"

# %%
from pydantic import BaseModel, Field

class ContactInfo(BaseModel):
    """Contact information for a person."""
    name: str = Field(description="The name of the person")
    emial: str = Field(description="The email adress of the person")
    phone: str = Field(description="the phone number of the person")
    tone: int = Field(description="the tone of the person", ge=0, le=100)
    age: int = Field(description="the age of the person")
    sentiment: str = Field(description="The sentiment onversation of the person")

llm_with_structured_output = llm.with_structured_output(schema=ContactInfo)

messages = [
    ("system", 'you are helpful assistant that can extrac information from a given conversation.'),
    ("user", "Hello, I'm Fredy my number is 502 43434343 and I'm 30 old")
]

response = llm_with_structured_output.invoke(messages)
response
# Out:
# ContactInfo(name='Fredy', emial='<UNKNOWN>', phone='502 43434343', tone=50, age=30, sentiment='neutral')

# %%
response.name
# Out:
# 'Fredy'
